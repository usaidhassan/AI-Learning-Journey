# %%
import pandas as pd

# %%
df = pd.read_csv('imdb_top250.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Title    250 non-null    object
#  1   Year     250 non-null    int64
#  2   Runtime  250 non-null    object
#  3   Rating   250 non-null    float64
#  4   Votes    250 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 9.9+ KB

# %%
df.describe()
# Out:
#              Year      Rating
# count   250.00000  250.000000
# mean   1989.44000    8.313600
# std      25.43861    0.234167
# min    1921.00000    8.000000
# 25%    1974.00000    8.100000
# 50%    1996.50000    8.200000
# 75%    2009.00000    8.400000
# max    2026.00000    9.300000

# %%
df.shape
# Out:
# (250, 5)

# %%
df['Rating'].sort_values(ascending=False).head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.1
# 3    9.0
# 4    9.0
# Name: Rating, dtype: float64

# %%
df.sort_values('Rating', ascending=False).head(10)
# Out:
#                                                  Title  Year Runtime  Rating  \
# 0                             The Shawshank Redemption  1994  2h 22m     9.3
# 1                                        The Godfather  1972  2h 55m     9.2
# 2                                      The Dark Knight  2008  2h 32m     9.1
# 3                                The Godfather Part II  1974  3h 22m     9.0
# 4                                         12 Angry Men  1957  1h 36m     9.0
# 5        The Lord of the Rings: The Return of the King  2003  3h 21m     9.0
# 6                                     Schindler's List  1993  3h 15m     9.0
# 119                   Attack on Titan: The Last Attack  2024  2h 25m     9.0
# 7    The Lord of the Rings: The Fellowship of the Ring  2001  2h 58m     8.9
# 11                                        Forrest Gump  1994  2h 22m     8.8
#
#       Votes
# 0    (3.2M)
# 1    (2.2M)
# 2    (3.2M)
# 3    (1.5M)
# 4    (991K)
# 5    (2.2M)
# 6    (1.6M)
# 119   (32K)
# ...

# %%
import matplotlib.pyplot as plt

df['Year'].value_counts().sort_index().plot(figsize=(12,5))

plt.title("Number of Top IMDb Movies by Release Year")
plt.xlabel("Year")
plt.ylabel("Count")

plt.show()
